# %% [markdown]
# Dataset: `bike_hour.csv`
# 1. Klasifikacija - Hoce li potraznja za biciklima biti velika?
# 2. Regresija - Ako hoce, koliko se ocekuje da ce biti iznajmljeno bicikala?
#
# Lista kolona koje nas zanimaju i nayivi u koje ih zelimo preimenovati:
# - season
# - yr -> year
# - mnth -> month
# - hr -> hour
# - holiday
# - weekday
# - workingday
# - temperature
# - humidity
# - windspeed
#
# - casual i registered NE zato jer zajedno predstavljaju cnt
#
# - cnt -> count - ovo nam je ciljana varijabla

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score,
                            accuracy_score, confusion_matrix,
                            ConfusionMatrixDisplay, classification_report)

pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
df = pd.read_csv('data/bike_hour.csv')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp  atemp  hum  windspeed  casual  registered  cnt
# 0           1  0.24   0.29 0.81       0.00       3          13   16
# 1           1  0.22   0.27 0.80       0.00       8          32   40
# 2           1  0.22   0.27 0.80       0.00       5          27   32
# 3           1  0.24   0.29 0.75       0.00       3          10   13
# 4           1  0.24   0.29 0.75       0.00       0           1    1

# %%
df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.shape
# Out:
# (17379, 17)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  str
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), str(1)
# memory usage: 2.3 MB

# %%
df = df.rename(columns={
    'yr': 'year',
    'mnth': 'month',
    'hr': 'hour',
    'hum': 'humidity',
    'cnt': 'count'
})

df
# Out:
#        instant      dteday  season  year  month  hour  holiday  weekday  \
# 0            1  2011-01-01       1     0      1     0        0        6
# 1            2  2011-01-01       1     0      1     1        0        6
# 2            3  2011-01-01       1     0      1     2        0        6
# 3            4  2011-01-01       1     0      1     3        0        6
# 4            5  2011-01-01       1     0      1     4        0        6
# ...        ...         ...     ...   ...    ...   ...      ...      ...
# 17374    17375  2012-12-31       1     1     12    19        0        1
# 17375    17376  2012-12-31       1     1     12    20        0        1
# 17376    17377  2012-12-31       1     1     12    21        0        1
# 17377    17378  2012-12-31       1     1     12    22        0        1
# 17378    17379  2012-12-31       1     1     12    23        0        1
#
#        workingday  weathersit  temp  atemp  humidity  windspeed  casual  \
# ...

# %%
df['count'].describe()
# Out:
# count   17,379.00
# mean       189.46
# std        181.39
# min          1.00
# 25%         40.00
# 50%        142.00
# 75%        281.00
# max        977.00
# Name: count, dtype: float64

# %%
df['count'].plot(
    kind='hist',
    figsize=(10, 5),
    bins=80,
    title='Distribucija broja iznajmljenih bicikala'
)

plt.grid(True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  str
#  2   season      17379 non-null  int64
#  3   year        17379 non-null  int64
#  4   month       17379 non-null  int64
#  5   hour        17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  humidity    17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  count       17379 non-null  int64
# dtypes: float64(4), int64(12), str(1)
# memory usage: 2.3 MB

# %% [markdown]
# hour
# workingday
# temp
# humidity
# windspeed
#
# count

# %%
features = ['hour', 'workingday', 'temp', 'humidity', 'windspeed']
treshold = df['count'].quantile(0.75)

df['high_demand'] = np.where(df['count'] >= treshold, 1, 0)
df['high_demand'].value_counts()
# Out:
# high_demand
# 0    13025
# 1     4354
# Name: count, dtype: int64

# %%
X_class = df[features]
y_class = df['high_demand']

X_train_class, X_test_class, y_train_class, y_test_class = train_test_split(
    X_class,
    y_class,
    test_size=0.25,
    random_state=42
)

# %%
class_model = DecisionTreeClassifier(max_depth=5, random_state=42)
class_model.fit(X_train_class, y_train_class)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred_class = class_model.predict(X_test_class)

# %%
accuracy = accuracy_score(y_test_class, y_pred_class)
accuracy
# Out:
# 0.8428078250863061

# %%
df_high = df[df['high_demand'] == 1].copy()
df_high.shape
# Out:
# (4354, 18)

# %%
X_reg = df_high[features]
y_reg = df_high['count']

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg,
    y_reg,
    test_size=0.25,
    random_state=42
)

# %%
reg_model = RandomForestRegressor(n_estimators=100, max_depth=8, random_state=42)
reg_model.fit(X_train_reg, y_train_reg)
# Out:
# RandomForestRegressor(max_depth=8, random_state=42)

# %%
y_pred_reg = reg_model.predict(X_test_reg)

# %%
mea = mean_absolute_error(y_test_reg, y_pred_reg)
mea
# Out:
# 78.60349169947106

# %%
r2 = r2_score(y_test_reg, y_pred_reg)
r2
# Out:
# 0.5049822889630248

# %%
reg_results_df = pd.DataFrame({
    'actual': y_test_reg.values,
    'predicted': y_pred_reg
})

reg_results_df
# Out:
#       actual  predicted
# 0        427     399.19
# 1        416     450.31
# 2        290     334.47
# 3        404     469.56
# 4        520     549.21
# ...      ...        ...
# 1084     523     568.86
# 1085     405     395.53
# 1086     424     381.10
# 1087     820     708.18
# 1088     466     562.19
#
# [1089 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(reg_results_df['actual'], reg_results_df['predicted'])
plt.xlabel('Stvarni podaci')
plt.ylabel('Predvideni podaci')
plt.grid(True)
plt.show()

# %%
new_data = pd.DataFrame({
    'hour': [10], 
    'workingday': [0],
    'temp': [0.7],
    'humidity': [0.35],
    'windspeed': [0.53]
})

new_data
# Out:
#    hour  workingday  temp  humidity  windspeed
# 0    10           0  0.70      0.35       0.53

# %%
predicted_class = class_model.predict(new_data)[0]
predicted_class
# Out:
# np.int64(1)

# %%
if predicted_class == 1:
    predicted_count = reg_model.predict(new_data)[0]
    print(predicted_count)
else:
    print('Nije velika potraznja')
# Out:
# 442.02212819561396
